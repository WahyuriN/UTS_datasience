# %% [markdown]
# <a href="https://colab.research.google.com/github/WahyuriN/UTS_datasience/blob/main/pertemuan1_Wahyu_Ari_Nugroho_240401010173.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nama : Wahyu Ari Nugroho
# # NIM : 240401010173
# # Kelas : IF401

# %% [markdown]
# # ================================================
# # PERTEMUAN 1: Notebook Pertama Data Science
# # ================================================

# %% [markdown]
# ```
# # SEL 1: Output sederhana
# ```

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %% [markdown]
# ```
# # SEL 2: Variabel dan tipe data dasar
# ```

# %%
nama = "Wahyu Ari Nugroho" # String
angkatan = 2024 # Integer
ipk = 3.04 # Float
aktif = True # Boolean

print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Wahyu Ari Nugroho
# Angkatan: 2024
# IPK : 3.04
# Aktif : True

# %% [markdown]
# ```
# # SEL 3: List dan perulangan
# ```

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %% [markdown]
# ```
# # SEL 4: Fungsi sederhana
# ```

# %%
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Wahyu Ari Nugroho", "Informatika", 2024)

print(hasil)
# Out:
# Hai! Saya Wahyu Ari Nugroho dari Informatika, angkatan 2024.

# %% [markdown]
# # Kesimpulan :

# %% [markdown]
# # praktikum pertama ini mempelajari dasar-dasar Python, yaitu menampilkan output, menggunakan variabel, membuat list dan perulangan, serta membuat dan memanggil fungsi.
